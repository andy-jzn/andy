# %%
import pandas as pd

# %%
df = pd.read_csv("state_data.csv")

# %%
print("Shape of DataFrame:", df.shape)
# Out:
# Shape of DataFrame: (52, 4)

# %%
## There are 52 rows and 4 columns

# %%
display(df.head())
# Out:
#   state   latitude   longitude        name
# 0    AK  63.588753 -154.493062      Alaska
# 1    AL  32.318231  -86.902298     Alabama
# 2    AR  35.201050  -91.831833    Arkansas
# 3    AZ  34.048928 -111.093731     Arizona
# 4    CA  36.778261 -119.417932  California

# %%
display(df.tail())
# Out:
#    state   latitude   longitude           name
# 47    VT  44.558803  -72.577841        Vermont
# 48    WA  47.751074 -120.740139     Washington
# 49    WI  43.784440  -88.787868      Wisconsin
# 50    WV  38.597626  -80.454903  West Virginia
# 51    WY  43.075968 -107.290284        Wyoming

# %%
"""
a) the different columns represent the state, the latitude, longitude and name
b) First state: Alaska
c) The last state: Wyoming
d) There are more than 50 states listed because it includes other US territories like Puerto Rico
# Out:
# '\na) the different columns represent the state, the latitude, longitude and name\nb) First state: Alaska\nc) The last state: Wyoming\nd) There are more than 50 states listed because the indexing starts at 0 and there are more than 50 states\n'

# %%
median_lat=df["latitude"].median()
median_lon=df["longitude"].median()

print(f"Median Latitude: ", median_lat)
print(f"Median Longiitude: ", median_lon)

df["dist_to_median_lat"] = (df["latitude"] - median_lat).abs()
df["dist_to_median_lon"] = (df["longitude"] - median_lon).abs()


print("New DataFrame shape:", df.shape)
# Out:
# Median Latitude:  39.4355155
# Median Longiitude:  -89.093198
# New DataFrame shape: (52, 6)

# %%
##There are 52 rows and 6 columns

# %%
# Closest and farthest by latitude
closest_lat_state = df.loc[df["dist_to_median_lat"].idxmin()]
farthest_lat_state = df.loc[df["dist_to_median_lat"].idxmax()]

# Closest and farthest by longitude
closest_lon_state = df.loc[df["dist_to_median_lon"].idxmin()]
farthest_lon_state = df.loc[df["dist_to_median_lon"].idxmax()]

print(f"Closest to median latitude: {closest_lat_state['state']} ({closest_lat_state['dist_to_median_lat']:.2f})")
print(f"Farthest from median latitude: {farthest_lat_state['state']} ({farthest_lat_state['dist_to_median_lat']:.2f})")
print(f"Closest to median longitude: {closest_lon_state['state']} ({closest_lon_state['dist_to_median_lon']:.2f})")
print(f"Farthest from median longitude: {farthest_lon_state['state']} ({farthest_lon_state['dist_to_median_lon']:.2f})")
# Out:
# Closest to median latitude: CO (0.11)
# Farthest from median latitude: AK (24.15)
# Closest to median longitude: IL (0.31)
# Farthest from median longitude: HI (66.57)
